# %%
import pandas as pd

# %% [markdown]
# data = pd.read_csv("pokemon.csv")
# data
# data2 = pd.read_csv("google_stock_price.csv")
# data2
# data2.head(10)
# data2.tail(10)

# %%
data.shape
data.head()
data2.shape
# Out:
# (3012, 1)

# %%
data = pd.read_csv("pokemon.csv", usecols=["Pokemon"], squeeze=True)
data2 = pd.read_csv("google_stock_price.csv", usecols=["Stock Price"], squeeze=True)
data.head()
data
data.shape
data
data.shape
data.dtype
data2
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
l1 = list(data)
l1
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
d1 = dict(data)
d1
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
data2.max()
# Out:
# 782.22

# %%
data2.min()
# Out:
# 49.95

# %%
data.max()
# Out:
# 'Zygarde'

# %%
data.min()
# Out:
# 'Abomasnow'

# %%
 print(len(data2))
 print(len(data))
# Out:
# 3012
# 721

# %%
print(type(data2))
print(type(data))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
sorted(data, reverse=True)
# Out:
# ['Zygarde',
#  'Zweilous',
#  'Zubat',
#  'Zorua',
#  'Zoroark',
#  'Zigzagoon',
#  'Zekrom',
#  'Zebstrika',
#  'Zapdos',
#  'Zangoose',
#  'Yveltal',
#  'Yanmega',
#  'Yanma',
#  'Yamask',
#  'Xerneas',
#  'Xatu',
#  'Wynaut',
#  'Wurmple',
#  'Wormadam',
#  'Wooper',
#  'Woobat',
#  'Wobbuffet',
#  'Wingull',
#  'Wigglytuff',
#  'Whismur',
#  'Whiscash',
#  'Whirlipede',
#  'Whimsicott',
#  'Weezing',
#  'Weepinbell',
#  'Weedle',
#  'Weavile',
#  'Watchog',
#  'Wartortle',
#  'Walrein',
#  'Wailord',
#  'Wailmer',
#  'Vulpix',
#  'Vullaby',
#  'Voltorb',
#  'Volcarona',
#  'Volcanion',
#  'Volbeat',
#  'Vivillon',
#  'Virizion',
#  'Vileplume',
#  'Vigoroth',
#  'Victreebel',
#  'Victini',
#  'Vibrava',
#  'Vespiquen',
#  'Venusaur',
#  'Venonat',
#  'Venomoth',
#  'Venipede',
#  'Vaporeon',
#  'Vanilluxe',
#  'Vanillite',
#  'Vanillish',
#  'Uxie',
#  'Ursaring',
#  'Unown',
#  'Unfezant',
#  'Umbreon',
#  'Tyrunt',
#  'Tyrogue',
#  'Tyrantrum',
#  'Tyranitar',
#  'Typhlosion',
# ...

# %%
 sorted(data2, reverse=True)
# Out:
# [782.22,
#  776.6,
#  773.18,
#  772.88,
#  771.61,
#  771.07,
#  771.0,
#  768.79,
#  767.04,
#  766.81,
#  766.61,
#  764.65,
#  763.25,
#  762.51,
#  762.38,
#  762.37,
#  759.14,
#  759.0,
#  758.88,
#  758.09,
#  756.6,
#  755.98,
#  753.93,
#  753.2,
#  752.67,
#  752.54,
#  752.0,
#  751.72,
#  751.61,
#  750.53,
#  750.31,
#  750.26,
#  750.0,
#  749.91,
#  749.46,
#  749.43,
#  748.4,
#  748.28,
#  748.15,
#  747.77,
#  747.77,
#  745.91,
#  745.69,
#  745.29,
#  744.95,
#  744.77,
#  743.62,
#  743.4,
#  743.09,
#  742.95,
#  742.74,
#  742.6,
#  742.58,
#  742.09,
#  741.84,
#  741.77,
#  741.19,
#  740.75,
#  740.28,
#  740.0,
#  739.77,
#  739.31,
#  739.15,
#  738.87,
#  738.63,
#  738.42,
#  738.41,
#  738.06,
#  737.8,
#  737.78,
#  737.6,
#  736.96,
#  736.1,
#  736.09,
#  735.72,
#  735.4,
#  735.3,
#  734.15,
#  733.78,
#  733.76,
#  733.53,
#  732.66,
#  731.25,
#  731.23,
#  730.96,
#  730.49,
#  730.4,
#  728.96,
#  728.58,
#  728.33,
#  728.32,
#  728.28,
# ...

# %%
data.values
data2.values
# Out:
# array([ 50.12,  54.1 ,  54.65, ..., 773.18, 771.61, 782.22])

# %%
print(data.is_unique)
print(data2.is_unique)
# Out:
# True
# False

# %%
print(data.ndim)
print(data2.ndim)
# Out:
# 1
# 1

# %%
data = pd.read_csv("pokemon.csv")
data2 = pd.read_csv("google_stock_price.csv", usecols=["Stock Price"], squeeze=True)
data.ndim
# Out:
# 2

# %%
data.shape
data2.shape
# Out:
# (3012,)

# %%
data2.name
# Out:
# 'Stock Price'

# %%
data2.name = "New Stock Price"
data2.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: New Stock Price, dtype: float64

# %%
data2.name
# Out:
# 'New Stock Price'

# %%
data = pd.read_csv("pokemon.csv", usecols=["Pokemon"], squeeze=True)
data2 = pd.read_csv("google_stock_price.csv", usecols=["Stock Price"], squeeze=True)

# %%
data.sort_values().head(10)
# Out:
# 459     Abomasnow
# 62           Abra
# 358         Absol
# 616      Accelgor
# 680     Aegislash
# 141    Aerodactyl
# 305        Aggron
# 189         Aipom
# 64       Alakazam
# 593     Alomomola
# Name: Pokemon, dtype: object

# %%
data.sort_values(ascending=False, inplace=True)
data.head()
data.tail(10)
# Out:
# 593     Alomomola
# 64       Alakazam
# 189         Aipom
# 305        Aggron
# 141    Aerodactyl
# 680     Aegislash
# 616      Accelgor
# 358         Absol
# 62           Abra
# 459     Abomasnow
# Name: Pokemon, dtype: object

# %%
data = pd.read_csv("pokemon.csv", usecols=["Pokemon"], squeeze=True)
data2 = pd.read_csv("google_stock_price.csv", usecols=["Stock Price"], squeeze=True)

# %%
data.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
data = pd.read_csv("pokemon.csv", index_col=["Pokemon"], squeeze=True)
data.value_counts()
# Out:
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Psychic      47
# Fire         47
# Rock         41
# Electric     36
# Ground       30
# Dark         28
# Poison       28
# Fighting     25
# Dragon       24
# Ghost        23
# Ice          23
# Steel        22
# Fairy        17
# Flying        3
# Name: Type, dtype: int64

# %%
data.value_counts().sum()
# Out:
# 721

# %%
data2 = pd.read_csv("google_stock_price.csv", usecols=["Stock Price"], squeeze=True)
data2
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
def perform(number):
    if number < 300:
        return "ok"
    elif number >=300 and number <700 :
        return "Satisfactory"
    else:
        return "Best"

# %%
data2.apply(perform).tail(20)
# Out:
# 2992    Best
# 2993    Best
# 2994    Best
# 2995    Best
# 2996    Best
# 2997    Best
# 2998    Best
# 2999    Best
# 3000    Best
# 3001    Best
# 3002    Best
# 3003    Best
# 3004    Best
# 3005    Best
# 3006    Best
# 3007    Best
# 3008    Best
# 3009    Best
# 3010    Best
# 3011    Best
# Name: Stock Price, dtype: object

# %%
print(data2.head())
data2.apply(lambda stock_price : stock_price+10).head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64
# 0    60.12
# 1    64.10
# 2    64.65
# 3    62.38
# 4    62.95
# Name: Stock Price, dtype: float64

# %%
x = lambda num : num*10
print(x(12))
# Out:
# 120

# %%
x = lambda a,b : a+b
print(x(2,3))
# Out:
# 5

# %%
data2.max()
# Out:
# 782.22

# %%
data2.min()
# Out:
# 49.95

# %%
data2.idxmax()
# Out:
# 3011

# %%
data2.idxmin()
# Out:
# 11

# %%
data2[11]
# Out:
# 49.95
